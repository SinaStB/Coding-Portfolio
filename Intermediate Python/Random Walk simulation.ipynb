# %% [markdown]
# ## What are the odds that you'll reach 60 steps high on the Empire State Building?

# %%
# numpy and matplotlib imported, seed set
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(123)

# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        # Set step: last element in random_walk
        step = random_walk[-1]
        # Roll the dice
        dice = np.random.randint(1,7)
        # Determine next step
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        # append next_step to random_walk
        random_walk.append(step)
    # Append random_walk to all_walks
    all_walks.append(random_walk)
    
# Convert all_walks to NumPy array: np_aw
np_aw = np.array(all_walks)

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.title("100 steps journey plot for 500 simulations")
plt.show()

# Select last row from np_aw_t: ends
ends = np_aw_t[-1,:]

# Plot histogram of ends, display plot
plt.hist(ends)
plt.title("Final floor after 100 steps distribution for 500 simulations")
plt.show()

# Final answer
chance = sum(ends >= 60)/500*100

# %%
print("There is a chance of " + '\033[1m' + str(chance) + '\033[0m'  + 
      "% to reach 60 steps high on the Empire State Building")
# Out:
# There is a chance of 78.4% to reach 60 steps high on the Empire State Building
